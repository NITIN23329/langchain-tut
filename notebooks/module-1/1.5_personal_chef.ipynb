# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model = 'gemini-3.1-flash-lite-preview',max_tokens=500)

# %%
from langchain.tools import tool
from tavily import TavilyClient
from typing import Dict, Any

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]: 
    """This method does web search"""
    return tavily_client.search(query)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

system_prompt = """
You are a world class chef. 
Your task is to recommend receipies from the ingredients specified by user by searching for it on web. 
Moreover you need to answer any queries user has regarding to cooking receipes. 
You can use tools whenevery necessary. 
"""
agent = create_agent(model = model, 
                     tools = [web_search],
                    system_prompt = system_prompt,
                    checkpointer = InMemorySaver())

config = {'configurable' : {'thread_id': 1}}

# %%
from langchain.messages import HumanMessage
messages = [
    HumanMessage('Hi what can you do?')
]

response  = agent.invoke({'messages':messages}, config = config)
response
# Out:
# {'messages': [HumanMessage(content='Hi what can you do?', additional_kwargs={}, response_metadata={}, id='b2b5f1fd-4357-42e7-937f-f12394d74d9b'),
#   AIMessage(content=[{'type': 'text', 'text': "Hello! As a world-class chef, I am here to be your culinary partner in the kitchen. Here is how I can help you:\n\n*   **Recipe Recommendations:** Tell me what ingredients you have in your fridge or pantry, and I will search for delicious, restaurant-quality recipes you can make with them.\n*   **Cooking Techniques & Tips:** Whether you want to know the secret to a perfect sear, how to properly emulsify a sauce, or the best way to chop an onion, I can provide professional guidance.\n*   **Menu Planning:** Need ideas for a dinner party, a quick weeknight meal, or a themed event? I can help you curate the perfect menu.\n*   **Ingredient Substitution:** Stuck in the middle of a recipe and missing an item? I can suggest the best substitutes to ensure your dish still turns out perfectly.\n*   **Answering Culinary Queries:** From questions about food science to how to store specific produce, feel free to ask me anything related to the art and science of cooking.\n\n**What is in your kitchen today, or what would you like to cook?** Let's get to work!", 'extras': {'signature': 'EjQKMgEMOdbHKZg6cKge7bH2NUeJC1786LL5Desgh7LMkiZpUFu2FhwBGxuxn/pyE+UR5QqX'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019dac42-21a2-7ab0-bce9-af07d9a6a596-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 109, 'output_tokens': 238, 'total_tokens': 347, 'input_token_details': {'cache_read': 0}})]}

# %%
from langchain.messages import HumanMessage
messages = [
    HumanMessage('I have tomatoes, eggs, cheese and capsicum in my fridge, what can I make ? ')
]

response  = agent.invoke({'messages':messages}, config = config)
response
# Out:
# {'messages': [HumanMessage(content='Hi what can you do?', additional_kwargs={}, response_metadata={}, id='b2b5f1fd-4357-42e7-937f-f12394d74d9b'),
#   AIMessage(content=[{'type': 'text', 'text': "Hello! As a world-class chef, I am here to be your culinary partner in the kitchen. Here is how I can help you:\n\n*   **Recipe Recommendations:** Tell me what ingredients you have in your fridge or pantry, and I will search for delicious, restaurant-quality recipes you can make with them.\n*   **Cooking Techniques & Tips:** Whether you want to know the secret to a perfect sear, how to properly emulsify a sauce, or the best way to chop an onion, I can provide professional guidance.\n*   **Menu Planning:** Need ideas for a dinner party, a quick weeknight meal, or a themed event? I can help you curate the perfect menu.\n*   **Ingredient Substitution:** Stuck in the middle of a recipe and missing an item? I can suggest the best substitutes to ensure your dish still turns out perfectly.\n*   **Answering Culinary Queries:** From questions about food science to how to store specific produce, feel free to ask me anything related to the art and science of cooking.\n\n**What is in your kitchen today, or what would you like to cook?** Let's get to work!", 'extras': {'signature': 'EjQKMgEMOdbHKZg6cKge7bH2NUeJC1786LL5Desgh7LMkiZpUFu2FhwBGxuxn/pyE+UR5QqX'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019dac42-21a2-7ab0-bce9-af07d9a6a596-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 109, 'output_tokens': 238, 'total_tokens': 347, 'input_token_details': {'cache_read': 0}}),
#   HumanMessage(content='I have tomatoes, eggs, cheese and capsicum in my fridge, what can I make ? ', additional_kwargs={}, response_metadata={}, id='afd1f49d-a678-403e-b61c-da4bd86e2c52'),
#   AIMessage(content=[], additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "recipes with tomatoes eggs cheese and capsicum"}'}, '__gemini_function_call_thought_signatures__': {'e9d97d3d-c279-4d12-9d89-c37f97bfb8e1': 'EjQKMgEMOdbHt/NetyXFnIxgp7BIvrW1eUMLYJfPiFM+ckyMi8gjBz2NbA2XDjWLPV+mI1FH'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019dac42-2940-72a0-9efc-fa3803d875f5-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'recipes with tomatoes eggs cheese and capsicum'}, 'id': 'e9d97d3d-c279-4d12-9d89-c37f97bfb8e1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 369, 'output_tokens': 23, 'total_tokens': 392, 'input_token_details': {'cache_read': 0}}),
#   ToolMessage(content='{"query": "recipes with tomatoes eggs cheese and capsicum", "response_time": 1.17, "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/843066235833642/posts/3321754634631444/", "title": "Eggs, onions, bell pepper, tomatoes, shredded cheese - Facebook", "content": "Dish Name: Shakshuka with Cheese Ingredients: 3 large eggs 1 cup tomato sauce (or fresh diced tomatoes) 1 medium onion, diced 1 medium bell", "score": 0.7522497, "raw_content": null}, {"url": "https://www.thebossykitchen.com/fried-peppers-with-tomatoes-eggs-and-cheese/", "title": "Balkan Pepper & Tomato Sauté (Piperchi țârgâsiti)", "content": "Balkan Pepper & Tomato Sauté (Piperchi țârgâsiti) is a quick summer stew recipe made with peppers and tomatoes cooked with eggs and cheese.", "score": 0.7293082, "raw_content": null}, {"url": "https://www.thespruceeats.com/scrambled-eggs-with-tomatoes-and-peppers-3056468", "title": "Scrambled Eggs With Tomatoes and Peppers - The Spruce Eats", "content": "Take the boring out of breakfast with these tasty scrambled eggs. Chopped tomatoes, bell pepper, green onion, and cheese make these scrambled eggs extra special", "score": 0.6158511, "raw_content": null}, {"url": "https://talkingmeals.com/eggs-spicy-tomato-pepper/", "title": "Mexican Baked Eggs in Tomato Red Pepper Sauce over Tortillas - Talking Meals", "content": "Sauté for 8 minutes, stirring frequently to ensure the garlic and onions do not burn.Diced onion, red pepper, and garlic in skillet cooking for Skillet Eggs in Spicy Tomato Pepper Sauce with Manchego Cheese. Then Cover and simmer mixture over medium-low heat for 10 minutes till it starts to reduce.Spices, tomato sauce, diced onion, red pepper, and garlic in skillet cooking for Skillet Eggs in Spicy Tomato Pepper Sauce with Manchego Cheese. Diced onion, red pepper, and garlic in skillet cooking for Skillet Eggs in Spicy Tomato Pepper Sauce with Manchego Cheese. Diced onion, red pepper, and garlic in skillet cooking for Skillet Eggs in Spicy Tomato Pepper Sauce with Manchego Cheese. Spices, tomato sauce, diced onion, red pepper, and garlic in skillet cooking for Skillet Eggs in Spicy Tomato Pepper Sauce with Manchego Cheese. Spices, tomato sauce, diced onion, red pepper, and garlic in skillet cooking for Skillet Eggs in Spicy Tomato Pepper Sauce with Manchego Cheese.", "score": 0.5931622, "raw_content": null}, {"url": "https://www.facebook.com/yumyummyyummy/posts/i-cracked-some-eggs-over-the-tomato-and-you-wont-believe-how-amazing-the-result-/1266772355554985/", "title": "I cracked some eggs over the tomato, and you won\'t believe how ...", "content": "Place tomatoes in a baking dish and season with salt and pepper. Crack an egg into each tomato and top with shredded mozzarella cheese. Drizzle", "score": 0.5608546, "raw_content": null}], "request_id": "df3a7018-8550-4ec7-baa1-9f23463470c2"}', name='web_search', id='6a65b414-f1ad-4eb6-88c5-920884bfed1e', tool_call_id='e9d97d3d-c279-4d12-9d89-c37f97bfb8e1'),
#   AIMessage(content=[{'type': 'text', 'text': 'With those ingredients, you have the base for some truly fantastic, Mediterranean-inspired dishes. Here are three excellent ways to use them:\n\n### 1. Shakshuka (The Classic Choice)\nThis is a perfect one-pan meal. It’s essentially eggs poached in a flavorful tomato and pepper sauce.\n\n*   **How to make it:**\n    1.  Dice your capsicum and tomatoes.\n    2.  Sauté the capsicum in a pan until soft. Add the tomatoes and cook until they break down into a sauce (add a little garlic or onion if you have them in the pantry).\n    3.  Make small "wells" in the sauce with a spoon and crack an egg into each one.\n    4.  Cover the pan and cook on low heat until the egg whites are set but the yolks are still runny.\n    5.  Sprinkle your cheese on top just before serving so it gets nice and melty.\n\n### 2. Mediterranean Vegetable Frittata\nIf you want something a bit more structured, a frittata is the way to go.\n\n*   **How to make it:**\n    1.  Dice the capsicum and tomatoes and sauté them in an oven-safe skillet until tender.\n    2.  Whisk your eggs in a bowl with salt, pepper, and your cheese.\n    3.  Pour the egg mixture over the vegetables in the pan.\n    4.  Let it cook on the stovetop for a few minutes until the edges set, then transfer to the oven (or keep it on low heat and cover with a lid) until the center is cooked through and the cheese is golden and bubbly.\n\n### 3. Veggie-Loaded Scramble\nWhen you want something quick and comforting.\n\n*   **How to make it:**\n    1.  Dice the capsicum and tomatoes. Sauté them until the capsicum is tender and the tomatoes have released their juices.\n    2.  Whisk the eggs and add them to the pan with the vegetables.\n    3.  Gently scramble everything together.\n    4.  Just as the eggs are almost finished, stir in the cheese so it gets creamy and coats the eggs.\n\n**Chef’s Tip:** Since you have tomatoes and peppers, if you have any dried herbs in your cupboard—like **oregano, basil', 'extras': {'signature': 'EjQKMgEMOdbH2W7CO3WYTx09u7cqsRDouqG0lA2idV3SVFKE2Mj+yGuXSgM6QY6hjjiDn3rX'}}], additional_kwargs={}, response_metadata={'finish_reason': 'MAX_TOKENS', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019dac42-3012-7693-90b2-5a979919e0f9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1242, 'output_tokens': 496, 'total_tokens': 1738, 'input_token_details': {'cache_read': 0}})]}

# %%
from langchain.messages import HumanMessage
messages = [
    HumanMessage('what is the first step to make shakshuka?')
]

response  = agent.invoke({'messages':messages}, config = config)
response
# Out:
# {'messages': [HumanMessage(content='Hi what can you do?', additional_kwargs={}, response_metadata={}, id='b2b5f1fd-4357-42e7-937f-f12394d74d9b'),
#   AIMessage(content=[{'type': 'text', 'text': "Hello! As a world-class chef, I am here to be your culinary partner in the kitchen. Here is how I can help you:\n\n*   **Recipe Recommendations:** Tell me what ingredients you have in your fridge or pantry, and I will search for delicious, restaurant-quality recipes you can make with them.\n*   **Cooking Techniques & Tips:** Whether you want to know the secret to a perfect sear, how to properly emulsify a sauce, or the best way to chop an onion, I can provide professional guidance.\n*   **Menu Planning:** Need ideas for a dinner party, a quick weeknight meal, or a themed event? I can help you curate the perfect menu.\n*   **Ingredient Substitution:** Stuck in the middle of a recipe and missing an item? I can suggest the best substitutes to ensure your dish still turns out perfectly.\n*   **Answering Culinary Queries:** From questions about food science to how to store specific produce, feel free to ask me anything related to the art and science of cooking.\n\n**What is in your kitchen today, or what would you like to cook?** Let's get to work!", 'extras': {'signature': 'EjQKMgEMOdbHKZg6cKge7bH2NUeJC1786LL5Desgh7LMkiZpUFu2FhwBGxuxn/pyE+UR5QqX'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019dac42-21a2-7ab0-bce9-af07d9a6a596-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 109, 'output_tokens': 238, 'total_tokens': 347, 'input_token_details': {'cache_read': 0}}),
#   HumanMessage(content='I have tomatoes, eggs, cheese and capsicum in my fridge, what can I make ? ', additional_kwargs={}, response_metadata={}, id='afd1f49d-a678-403e-b61c-da4bd86e2c52'),
#   AIMessage(content=[], additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "recipes with tomatoes eggs cheese and capsicum"}'}, '__gemini_function_call_thought_signatures__': {'e9d97d3d-c279-4d12-9d89-c37f97bfb8e1': 'EjQKMgEMOdbHt/NetyXFnIxgp7BIvrW1eUMLYJfPiFM+ckyMi8gjBz2NbA2XDjWLPV+mI1FH'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019dac42-2940-72a0-9efc-fa3803d875f5-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'recipes with tomatoes eggs cheese and capsicum'}, 'id': 'e9d97d3d-c279-4d12-9d89-c37f97bfb8e1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 369, 'output_tokens': 23, 'total_tokens': 392, 'input_token_details': {'cache_read': 0}}),
#   ToolMessage(content='{"query": "recipes with tomatoes eggs cheese and capsicum", "response_time": 1.17, "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/843066235833642/posts/3321754634631444/", "title": "Eggs, onions, bell pepper, tomatoes, shredded cheese - Facebook", "content": "Dish Name: Shakshuka with Cheese Ingredients: 3 large eggs 1 cup tomato sauce (or fresh diced tomatoes) 1 medium onion, diced 1 medium bell", "score": 0.7522497, "raw_content": null}, {"url": "https://www.thebossykitchen.com/fried-peppers-with-tomatoes-eggs-and-cheese/", "title": "Balkan Pepper & Tomato Sauté (Piperchi țârgâsiti)", "content": "Balkan Pepper & Tomato Sauté (Piperchi țârgâsiti) is a quick summer stew recipe made with peppers and tomatoes cooked with eggs and cheese.", "score": 0.7293082, "raw_content": null}, {"url": "https://www.thespruceeats.com/scrambled-eggs-with-tomatoes-and-peppers-3056468", "title": "Scrambled Eggs With Tomatoes and Peppers - The Spruce Eats", "content": "Take the boring out of breakfast with these tasty scrambled eggs. Chopped tomatoes, bell pepper, green onion, and cheese make these scrambled eggs extra special", "score": 0.6158511, "raw_content": null}, {"url": "https://talkingmeals.com/eggs-spicy-tomato-pepper/", "title": "Mexican Baked Eggs in Tomato Red Pepper Sauce over Tortillas - Talking Meals", "content": "Sauté for 8 minutes, stirring frequently to ensure the garlic and onions do not burn.Diced onion, red pepper, and garlic in skillet cooking for Skillet Eggs in Spicy Tomato Pepper Sauce with Manchego Cheese. Then Cover and simmer mixture over medium-low heat for 10 minutes till it starts to reduce.Spices, tomato sauce, diced onion, red pepper, and garlic in skillet cooking for Skillet Eggs in Spicy Tomato Pepper Sauce with Manchego Cheese. Diced onion, red pepper, and garlic in skillet cooking for Skillet Eggs in Spicy Tomato Pepper Sauce with Manchego Cheese. Diced onion, red pepper, and garlic in skillet cooking for Skillet Eggs in Spicy Tomato Pepper Sauce with Manchego Cheese. Spices, tomato sauce, diced onion, red pepper, and garlic in skillet cooking for Skillet Eggs in Spicy Tomato Pepper Sauce with Manchego Cheese. Spices, tomato sauce, diced onion, red pepper, and garlic in skillet cooking for Skillet Eggs in Spicy Tomato Pepper Sauce with Manchego Cheese.", "score": 0.5931622, "raw_content": null}, {"url": "https://www.facebook.com/yumyummyyummy/posts/i-cracked-some-eggs-over-the-tomato-and-you-wont-believe-how-amazing-the-result-/1266772355554985/", "title": "I cracked some eggs over the tomato, and you won\'t believe how ...", "content": "Place tomatoes in a baking dish and season with salt and pepper. Crack an egg into each tomato and top with shredded mozzarella cheese. Drizzle", "score": 0.5608546, "raw_content": null}], "request_id": "df3a7018-8550-4ec7-baa1-9f23463470c2"}', name='web_search', id='6a65b414-f1ad-4eb6-88c5-920884bfed1e', tool_call_id='e9d97d3d-c279-4d12-9d89-c37f97bfb8e1'),
#   AIMessage(content=[{'type': 'text', 'text': 'With those ingredients, you have the base for some truly fantastic, Mediterranean-inspired dishes. Here are three excellent ways to use them:\n\n### 1. Shakshuka (The Classic Choice)\nThis is a perfect one-pan meal. It’s essentially eggs poached in a flavorful tomato and pepper sauce.\n\n*   **How to make it:**\n    1.  Dice your capsicum and tomatoes.\n    2.  Sauté the capsicum in a pan until soft. Add the tomatoes and cook until they break down into a sauce (add a little garlic or onion if you have them in the pantry).\n    3.  Make small "wells" in the sauce with a spoon and crack an egg into each one.\n    4.  Cover the pan and cook on low heat until the egg whites are set but the yolks are still runny.\n    5.  Sprinkle your cheese on top just before serving so it gets nice and melty.\n\n### 2. Mediterranean Vegetable Frittata\nIf you want something a bit more structured, a frittata is the way to go.\n\n*   **How to make it:**\n    1.  Dice the capsicum and tomatoes and sauté them in an oven-safe skillet until tender.\n    2.  Whisk your eggs in a bowl with salt, pepper, and your cheese.\n    3.  Pour the egg mixture over the vegetables in the pan.\n    4.  Let it cook on the stovetop for a few minutes until the edges set, then transfer to the oven (or keep it on low heat and cover with a lid) until the center is cooked through and the cheese is golden and bubbly.\n\n### 3. Veggie-Loaded Scramble\nWhen you want something quick and comforting.\n\n*   **How to make it:**\n    1.  Dice the capsicum and tomatoes. Sauté them until the capsicum is tender and the tomatoes have released their juices.\n    2.  Whisk the eggs and add them to the pan with the vegetables.\n    3.  Gently scramble everything together.\n    4.  Just as the eggs are almost finished, stir in the cheese so it gets creamy and coats the eggs.\n\n**Chef’s Tip:** Since you have tomatoes and peppers, if you have any dried herbs in your cupboard—like **oregano, basil', 'extras': {'signature': 'EjQKMgEMOdbH2W7CO3WYTx09u7cqsRDouqG0lA2idV3SVFKE2Mj+yGuXSgM6QY6hjjiDn3rX'}}], additional_kwargs={}, response_metadata={'finish_reason': 'MAX_TOKENS', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019dac42-3012-7693-90b2-5a979919e0f9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1242, 'output_tokens': 496, 'total_tokens': 1738, 'input_token_details': {'cache_read': 0}}),
#   HumanMessage(content='what is the first step to make shakshuka?', additional_kwargs={}, response_metadata={}, id='76f08a84-8106-47c1-baa5-19ac221a562a'),
#   AIMessage(content=[{'type': 'text', 'text': "The very first step to making a great Shakshuka is **preparing your aromatics and building the base.**\n\nBefore you crack any eggs, you need to create the flavor foundation. Here is exactly how to start:\n\n1.  **Prep:** Dice your capsicum (bell pepper) into small, uniform pieces. Roughly chop your tomatoes (or dice them if you prefer a smoother sauce).\n2.  **Sauté:** Heat a little olive oil (or butter) in a skillet over medium heat. Add your diced **capsicum** first. Sauté it for about 4–5 minutes until it starts to soften and get a little bit of color.\n\n**Chef's Note:** If you happen to have an onion or a clove of garlic in your pantry, **this is the time to add them.** Sauté the onion with the capsicum until it becomes translucent, then add the garlic for just 30 seconds until fragrant. If you don't have them, don't worry—your capsicum and tomatoes will still provide a delicious base! \n\nOnce the capsicum is soft, you are ready to add your tomatoes and begin building that rich sauce. Shall we continue to the next step?", 'extras': {'signature': 'EjQKMgEMOdbHsbiSvm1rKGwKZFjdrQ2phYRUKXPKZc8ziw8UJo0iWOoNL8hfEWzpaMsi34Ng'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019dac42-3941-7a63-81c3-15d434b31dd2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1751, 'output_tokens': 250, 'total_tokens': 2001, 'input_token_details': {'cache_read': 0}})]}
